# %%
import pandas as pd
import numpy as np

# %%
locations = pd.read_excel('Datasets/School locations.xlsx')

# %%
df = pd.read_csv('Datasets/survey_client_with_churn.csv')

# %%
customers_list = list(df['Customer heading'].unique())
len(customers_list)
# Out:
# 821

# %%
locations = locations[locations['Customer heading'].isin(customers_list)]
locations = locations.drop(['Province', 'Region', 'Town'], axis=1)

# %%
locations['Current Seller id'] = locations['Current Seller id'].astype(int)

# %% [markdown]
# #### Number of customers each Seller serve

# %%
num_customers = locations.groupby('Current Seller id')['Customer heading'].count()

# %%
locations
# Out:
#        Customer heading   Latitude  Longitude  Current Seller id Institution  \
# 7315             136369  40.428274  -3.681298                208          No
# 7316             136370  40.408230  -3.676975                208          No
# 7317             136372  40.372197  -3.760104                208          No
# 7318             136377  40.603361  -3.712042                117         Yes
# 7319             136378  40.242364  -3.704871                189          No
# ...                 ...        ...        ...                ...         ...
# 20091            212529  40.444196  -3.701910                208          No
# 20111            212675  40.432243  -3.694464                161          No
# 20116            212705  40.462455  -3.776128                189         Yes
# 20118            212717  40.440356  -3.628420                209          No
# 20119            212719  40.456178  -3.594880                209          No
#
#       Titularity
# 7315    Catholic
# 7316    Catholic
# 7317    Catholic
# 7318      Public
# 7319    Catholic
# ...          ...
# 20091   Catholic
# 20111   Catholic
# 20116    Private
# 20118    Private
# 20119    Private
#
# [821 rows x 6 columns]

# %%
locations['Num customers of seller'] = locations.replace({'Current Seller id': num_customers})['Current Seller id']

# %% [markdown]
# #### Area and density that each Seller serve

# %%
def shoelace_area_polygon(x,y): # shoelace formula
    return 0.5*np.abs(np.dot(x,np.roll(y,1))-np.dot(y,np.roll(x,1)))

# %%
sellers_list = list(locations['Current Seller id'].unique())

area_covered = {}

for seller in sellers_list:
    lat = locations.loc[locations['Current Seller id'] == seller, 'Latitude'].values
    long = locations.loc[locations['Current Seller id'] == seller, 'Longitude'].values
    area = shoelace_area_polygon(lat, long)
    area_covered[seller] = area

# %%
locations['Area covered by seller'] = locations.replace({'Current Seller id': area_covered})['Current Seller id']

# %%
locations.head()
# Out:
#       Customer heading   Latitude  Longitude  Current Seller id Institution  \
# 7315            136369  40.428274  -3.681298                208          No
# 7316            136370  40.408230  -3.676975                208          No
# 7317            136372  40.372197  -3.760104                208          No
# 7318            136377  40.603361  -3.712042                117         Yes
# 7319            136378  40.242364  -3.704871                189          No
#
#      Titularity  Num customers of seller  Area covered by seller
# 7315   Catholic                       47                0.026531
# 7316   Catholic                       47                0.026531
# 7317   Catholic                       47                0.026531
# 7318     Public                       58                0.193443
# 7319   Catholic                       57                0.028342

# %% [markdown]
# #### Titularity portfolio % each Seller serve

# %%
catholic_covered = {}
private_covered = {}

for seller in sellers_list:
    catholic_covered[seller] = locations[locations['Current Seller id'] == 100].Titularity.value_counts()['Catholic']
    private_covered[seller] = locations[locations['Current Seller id'] == 100].Titularity.value_counts()['Private']

# %%
locations.groupby('Titularity')['Customer heading'].count()
# Out:
# Titularity
# Catholic    178
# Private     130
# Public      513
# Name: Customer heading, dtype: int64

# %%
locations
# Out:
#        Customer heading   Latitude  Longitude  Current Seller id Institution  \
# 7315             136369  40.428274  -3.681298                208          No
# 7316             136370  40.408230  -3.676975                208          No
# 7317             136372  40.372197  -3.760104                208          No
# 7318             136377  40.603361  -3.712042                117         Yes
# 7319             136378  40.242364  -3.704871                189          No
# ...                 ...        ...        ...                ...         ...
# 20091            212529  40.444196  -3.701910                208          No
# 20111            212675  40.432243  -3.694464                161          No
# 20116            212705  40.462455  -3.776128                189         Yes
# 20118            212717  40.440356  -3.628420                209          No
# 20119            212719  40.456178  -3.594880                209          No
#
#       Titularity  Num customers of seller  Area covered by seller
# 7315    Catholic                       47                0.026531
# 7316    Catholic                       47                0.026531
# 7317    Catholic                       47                0.026531
# 7318      Public                       58                0.193443
# 7319    Catholic                       57                0.028342
# ...          ...                      ...                     ...
# 20091   Catholic                       47                0.026531
# 20111   Catholic                       65                0.016538
# 20116    Private                       57                0.028342
# 20118    Private                       53                0.028683
# 20119    Private                       53                0.028683
#
# [821 rows x 8 columns]

# %%
locations['Seller portfolio - Catholic (abs)'] = locations.replace({'Current Seller id': catholic_covered})['Current Seller id'] / 178
locations['Seller portfolio - Private (abs)'] = locations.replace({'Current Seller id': private_covered})['Current Seller id'] / 130

locations['Seller portfolio - Catholic (relative)'] = locations.replace({'Current Seller id': catholic_covered})['Current Seller id'] / locations['Num customers of seller']
locations['Seller portfolio - Private (relative)'] = locations.replace({'Current Seller id': private_covered})['Current Seller id'] / locations['Num customers of seller']

# %% [markdown]
# #### Institution % of Seller

# %%
locations.groupby('Institution')['Customer heading'].count()
# Out:
# Institution
# No     228
# Yes    593
# Name: Customer heading, dtype: int64

# %%
institution_yes = locations[locations.Institution=='Yes'].groupby(['Current Seller id'])['Customer heading'].count()

locations['Institution = Yes % (relative)'] = locations.replace({'Current Seller id': institution_yes})['Current Seller id'] / locations['Num customers of seller']
locations['Institution = Yes % (abs)'] = locations.replace({'Current Seller id': institution_yes})['Current Seller id'] / 593

# %%
locations = locations.drop(['Latitude', 'Longitude', 'Current Seller id'], axis=1)
# Out:
#        Customer heading Institution Titularity  Num customers of seller  \
# 7315             136369          No   Catholic                       47
# 7316             136370          No   Catholic                       47
# 7317             136372          No   Catholic                       47
# 7318             136377         Yes     Public                       58
# 7319             136378          No   Catholic                       57
# ...                 ...         ...        ...                      ...
# 20091            212529          No   Catholic                       47
# 20111            212675          No   Catholic                       65
# 20116            212705         Yes    Private                       57
# 20118            212717          No    Private                       53
# 20119            212719          No    Private                       53
#
#        Area covered by seller  Seller portfolio - Catholic (abs)  \
# 7315                 0.026531                           0.039326
# 7316                 0.026531                           0.039326
# 7317                 0.026531                           0.039326
# 7318                 0.193443                           0.039326
# 7319                 0.028342                           0.039326
# ...                       ...                                ...
# 20091                0.026531                           0.039326
# 20111                0.016538                           0.039326
# 20116                0.028342                           0.039326
# 20118                0.028683                           0.039326
# 20119                0.028683                           0.039326
#
#        Seller portfolio - Private (abs)  \
# 7315                           0.023077
# 7316                           0.023077
# 7317                           0.023077
# 7318                           0.023077
# 7319                           0.023077
# ...                                 ...
# 20091                          0.023077
# 20111                          0.023077
# 20116                          0.023077
# 20118                          0.023077
# 20119                          0.023077
#
#        Seller portfolio - Catholic (relative)  \
# 7315                                 0.148936
# 7316                                 0.148936
# 7317                                 0.148936
# 7318                                 0.120690
# 7319                                 0.122807
# ...                                       ...
# 20091                                0.148936
# 20111                                0.107692
# 20116                                0.122807
# 20118                                0.132075
# 20119                                0.132075
#
#        Seller portfolio - Private (relative)  Institution = Yes % (relative)  \
# 7315                                0.063830                        0.468085
# 7316                                0.063830                        0.468085
# 7317                                0.063830                        0.468085
# 7318                                0.051724                        0.879310
# 7319                                0.052632                        0.473684
# ...                                      ...                             ...
# 20091                               0.063830                        0.468085
# 20111                               0.046154                        0.230769
# 20116                               0.052632                        0.473684
# 20118                               0.056604                        0.603774
# 20119                               0.056604                        0.603774
#
#        Institution = Yes % (abs)
# 7315                    0.037099
# 7316                    0.037099
# 7317                    0.037099
# 7318                    0.086003
# 7319                    0.045531
# ...                          ...
# 20091                   0.037099
# 20111                   0.025295
# 20116                   0.045531
# 20118                   0.053963
# 20119                   0.053963
#
# [821 rows x 11 columns]
